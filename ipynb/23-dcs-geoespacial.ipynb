# %% [markdown]
# # _Dataviz Code Session_: Dados Geoespaciais

# %% [markdown]
# ## Objetivos da DCS
#
# - Aplicar técnicas de dataviz para plotagem e manipulação de representações visuais geoespaciais relacionadas a campos e poços de petróleo em bacias sedimentares brasileiras.

# %% [markdown]
# ## Ferramentas utilizadas
#
# - Módulos Python
#     - `numpy`
#     - `pandas`
#     - `matplotlib`
#     - `seaborn`
#     - `geopandas`

# %% [markdown]
# ## Aplicação do modelo referencial
#
# - Vide {numref}`Capítulo %s <cap:estetica>`.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sb, geopandas as geo

# %%
from warnings import filterwarnings; filterwarnings('ignore');

# %% [markdown]
# ### Dados de entrada

# %% [markdown]
# - Shapefiles dos campos de produção (ANP) - [[Fonte]](https://www.gov.br/anp/pt-br/assuntos/exploracao-e-producao-de-oleo-e-gas/dados-tecnicos/shapefile-de-dados)

# %%
geocp = geo.read_file('../data/ANP_campos_shp/CAMPOS_PRODUCAO_SIRGASPolygon.shp')

# %%
geocp
# Out:
#          NUM_RODADA             NOM_CAMPO   AREA  \
# 0         Rodada 11                 IRARA    6.0
# 1          Rodada 0               PESCADA   55.0
# 2          Rodada 0                 SALGO   11.0
# 3          Rodada 0               CAXAREU   34.0
# 4          Rodada 0                 CEXIS   54.0
# ..              ...                   ...    ...
# 422             AM2       Porto do Mangue    6.0
# 423        Rodada 0         MIRANGA LESTE    1.0
# 424  Rodada 13 (AM)              SÃO JOÃO    6.0
# 425        Rodada 9         GAVIÃO CARIJÓ  163.0
# 426        Rodada 0  LESTE DE POÇO XAVIER   22.0
#
#                                            OPERADOR_C         NUM_CONTRA  \
# 0                            BGM Petróleo e Gás Ltda.  48610005457201381
# 1                            Petróleo Brasileiro S.A.    480000039129784
# 2                            Petróleo Brasileiro S.A.    480000038419738
# 3                            Petróleo Brasileiro S.A.    480000035609749
# 4                                   3R Candeias  S.A.    480000036419749
# ..                                                ...                ...
# 422  Máxima 07 Exploração e Produção de Petróleo Ltda  48610007488200648
# 423                          Petróleo Brasileiro S.A.    480000036759761
# 424                       Petro-Victory Energia Ltda.  48610002005201691
# 425                                        Eneva S.A.  48610001413200815
# 426                                 Potiguar E&P S.A.      4861000400098
#
#      DAT_ASSINA DAT_TERMIN       NOM_BACIA  COD_CAMPO SIG_CAMPO  DAT_DESCOB  \
# 0           NaN        NaN  Espírito Santo     4841.0      IRAR  03/01/2022
# 1    06-08-1998        NaN        Potiguar      213.0        PE  24-10-1980
# 2    06-08-1998        NaN         Sergipe      275.0        SG  01-12-1984
# 3    06/08/1998        NaN          Campos     1164.0       CXR  07-08-2002
# 4    06-08-1998        NaN       Recôncavo       88.0        CX  07-03-1966
# ..          ...        ...             ...        ...       ...         ...
# 422         NaN        NaN        Potiguar     4535.0      4201  10/10/2011
# 423         NaN        NaN       Recôncavo      182.0       MGL         NaN
# 424   12/5/2016        NaN    Barreirinhas     4695.0        SJ  01/08/1966
# 425         NaN        NaN        Parnaíba     4629.0      GVCA         NaN
# 426         NaN        NaN        Potiguar      167.0       LPX         NaN
#
#      DAT_INICIO                                        ETAPA  MED_LAMINA  \
# 0    13/07/2022                                     Produção         0.0
# 1    01-05-1999                                     Produção        19.0
# 2    31-12-1986                                 Em Devolução        14.0
# 3           NaN                              Desenvolvimento      1141.0
# 4    30-06-1966                                     Produção         0.0
# ..          ...                                          ...         ...
# 422         NaN  Plano de Avaliação (Teste de longa duração)         0.0
# 423         NaN                                 Em Devolução         0.0
# 424  01/07/2020                                     Produção         0.0
# 425         NaN                              Desenvolvimento         0.0
# 426         NaN                                     Produção         0.0
#
#     FLUIDO_PRI      ID                                           geometry
# 0         ÓLEO  2460.0  POLYGON ((-39.81288 -19.25048, -39.81288 -19.2...
# 1          GÁS  1100.0  POLYGON ((-36.76596 -4.73997, -36.76856 -4.739...
# 2         ÓLEO  1102.0  POLYGON ((-36.57586 -10.63324, -36.57846 -10.6...
# 3         ÓLEO  1125.0  POLYGON ((-40.07812 -21.39323, -40.07812 -21.3...
# 4          GÁS  1126.0  POLYGON ((-38.46390 -12.62544, -38.46130 -12.6...
# ..         ...     ...                                                ...
# 422        NaN  2623.0  POLYGON ((-36.79461 -5.09674, -36.79461 -5.099...
# 423     OUTROS  2661.0  POLYGON ((-38.14358 -12.32336, -38.14619 -12.3...
# 424       Óleo  2662.0  POLYGON ((-43.32852 -2.59932, -43.32852 -2.596...
# 425        GÁS  2700.0  POLYGON ((-44.33073 -5.66927, -44.33073 -5.684...
# 426       ÓLEO  2701.0  POLYGON ((-37.67708 -5.52122, -37.67448 -5.521...
#
# [427 rows x 17 columns]

# %% [markdown]
# - Shapefiles do território nacional

# %%
geobr = geo.read_file('../data/gadm36_BRA_shp/gadm36_BRA_1.shp')

# %%
geobr
# Out:
#    GID_0  NAME_0     GID_1               NAME_1             VARNAME_1  \
# 0    BRA  Brazil   BRA.1_1                 Acre                   NaN
# 1    BRA  Brazil   BRA.2_1              Alagoas                   NaN
# 2    BRA  Brazil   BRA.3_1                Amapá                   NaN
# 3    BRA  Brazil   BRA.4_1             Amazonas               Amazone
# 4    BRA  Brazil   BRA.5_1                Bahia                  Ba¡a
# 5    BRA  Brazil   BRA.6_1                Ceará                   NaN
# 6    BRA  Brazil   BRA.7_1     Distrito Federal                   NaN
# 7    BRA  Brazil   BRA.8_1       Espírito Santo        Espiritu Santo
# 8    BRA  Brazil   BRA.9_1                Goiás           Goiáz|Goyáz
# 9    BRA  Brazil  BRA.10_1             Maranhão  São Luíz de Maranhão
# 10   BRA  Brazil  BRA.12_1          Mato Grosso          Matto Grosso
# 11   BRA  Brazil  BRA.11_1   Mato Grosso do Sul                   NaN
# 12   BRA  Brazil  BRA.13_1         Minas Gerais    Minas|Minas Geraes
# 13   BRA  Brazil  BRA.14_1                 Pará                   NaN
# 14   BRA  Brazil  BRA.15_1              Paraíba              Parahyba
# 15   BRA  Brazil  BRA.16_1               Paraná                   NaN
# 16   BRA  Brazil  BRA.17_1           Pernambuco            Pernambouc
# 17   BRA  Brazil  BRA.18_1                Piauí                Piauhy
# 18   BRA  Brazil  BRA.19_1       Rio de Janeiro                   NaN
# 19   BRA  Brazil  BRA.20_1  Rio Grande do Norte                   NaN
# 20   BRA  Brazil  BRA.21_1    Rio Grande do Sul                   NaN
# 21   BRA  Brazil  BRA.22_1             Rondônia               Guaporé
# 22   BRA  Brazil  BRA.23_1              Roraima            Rio Branco
# 23   BRA  Brazil  BRA.24_1       Santa Catarina       Santa Catharina
# 24   BRA  Brazil  BRA.25_1            São Paulo                   NaN
# 25   BRA  Brazil  BRA.26_1              Sergipe                   NaN
# 26   BRA  Brazil  BRA.27_1            Tocantins                   NaN
#
#     NL_NAME_1            TYPE_1         ENGTYPE_1  CC_1 HASC_1  \
# 0         NaN            Estado             State   NaN  BR.AC
# 1         NaN            Estado             State   NaN  BR.AL
# 2         NaN            Estado             State   NaN  BR.AP
# 3         NaN            Estado             State   NaN  BR.AM
# 4         NaN            Estado             State   NaN  BR.BA
# 5         NaN            Estado             State   NaN  BR.CE
# 6         NaN  Distrito Federal  Federal District   NaN  BR.DF
# 7         NaN            Estado             State   NaN  BR.ES
# 8         NaN            Estado             State   NaN  BR.GO
# 9         NaN            Estado             State   NaN  BR.MA
# 10        NaN            Estado             State   NaN  BR.MT
# 11        NaN            Estado             State   NaN  BR.MS
# 12        NaN            Estado             State   NaN  BR.MG
# 13        NaN            Estado             State   NaN  BR.PA
# 14        NaN            Estado             State   NaN  BR.PB
# 15        NaN            Estado             State   NaN  BR.PR
# 16        NaN            Estado             State   NaN  BR.PE
# 17        NaN            Estado             State   NaN  BR.PI
# 18        NaN            Estado             State   NaN  BR.RJ
# 19        NaN            Estado             State   NaN  BR.RN
# 20        NaN            Estado             State   NaN  BR.RS
# 21        NaN            Estado             State   NaN  BR.RO
# 22        NaN            Estado             State   NaN  BR.RR
# 23        NaN            Estado             State   NaN  BR.SC
# 24        NaN            Estado             State   NaN  BR.SP
# 25        NaN            Estado             State   NaN  BR.SE
# 26        NaN            Estado             State   NaN  BR.TO
#
#                                              geometry
# 0   POLYGON ((-68.10553 -10.72192, -68.10547 -10.7...
# 1   MULTIPOLYGON (((-35.88986 -9.84431, -35.88986 ...
# 2   MULTIPOLYGON (((-50.82570 2.52208, -50.82570 2...
# 3   POLYGON ((-58.13699 -7.35614, -58.13682 -7.356...
# 4   MULTIPOLYGON (((-38.69208 -17.95958, -38.69208...
# 5   MULTIPOLYGON (((-40.83181 -2.88125, -40.83181 ...
# 6   POLYGON ((-47.93915 -16.05135, -48.02110 -16.0...
# 7   MULTIPOLYGON (((-40.88403 -21.16125, -40.88403...
# 8   POLYGON ((-49.00480 -18.53718, -49.01248 -18.5...
# 9   MULTIPOLYGON (((-44.54986 -1.88458, -44.54986 ...
# 10  POLYGON ((-52.47143 -16.12672, -52.48842 -16.1...
# 11  POLYGON ((-54.16836 -23.99920, -54.17063 -24.0...
# 12  POLYGON ((-50.84402 -19.96758, -50.85332 -19.9...
# 13  MULTIPOLYGON (((-47.29792 -0.63375, -47.29792 ...
# 14  MULTIPOLYGON (((-43.01208 -9.40801, -43.01453 ...
# 15  MULTIPOLYGON (((-48.36514 -25.73403, -48.36514...
# 16  MULTIPOLYGON (((-35.13597 -8.83792, -35.13597 ...
# 17  POLYGON ((-42.69078 -9.54547, -42.69122 -9.545...
# 18  MULTIPOLYGON (((-44.67125 -23.35458, -44.67125...
# 19  MULTIPOLYGON (((-35.10958 -6.19375, -35.10958 ...
# 20  MULTIPOLYGON (((-52.07069 -32.02847, -52.07069...
# 21  POLYGON ((-62.89219 -12.86014, -62.89212 -12.8...
# 22  POLYGON ((-60.03790 0.26349, -60.04676 0.23211...
# 23  MULTIPOLYGON (((-48.54236 -27.93180, -48.54236...
# 24  MULTIPOLYGON (((-48.08236 -25.28431, -48.08236...
# 25  MULTIPOLYGON (((-37.38458 -11.45986, -37.38458...
# 26  POLYGON ((-49.23736 -12.88397, -49.23532 -12.8...

# %% [markdown]
# - Planilhas de poços públicos (2022 e 2023)

# %%
p2022 = pd.read_excel('../data/ANP_pocos_publicos/planilha-pocos-publicos-2022.xlsx')
p2023 = pd.read_excel('../data/ANP_pocos_publicos/planilha-pocos-publicos-2023.xlsx')

# %% [markdown]
# ### Processamento

# %%
def filter_by_state(state,fluid,phase):
    """Seleciona poços e campos para estado, bacia e propriedades especificados."""
    
    a = p2022[p2022.ESTADO == state[0]]
    b = p2023[p2023.ESTADO == state[0]]
    c = geobr[geobr.NAME_1 == state[1]]
    d = geocp[(geocp.NOM_BACIA == basin) & (geocp.FLUIDO_PRI == fluid) & (geocp.ETAPA == phase)]
    
    return a, b, c, d

# %% [markdown]
# - Escolha de parâmetros e aplicação de filtragem

# %%
state = ('BA','Bahia')
basin = 'Recôncavo'
fluid = 'ÓLEO'
stage = 'Produção'
p2022_s, p2023_s, geo_s, geo_cp = filter_by_state(state,fluid,stage)

# %%
# casting de coordenadas
p2023_s['LATITUDE_BASE_DD'] = p2023_s['LATITUDE_BASE_DD'].str.replace(',','.').astype(float)
p2023_s['LONGITUDE_BASE_DD'] = p2023_s['LONGITUDE_BASE_DD'].str.replace(',','.').astype(float)

# %% [markdown]
# ### Visualizações

# %% [markdown]
# - Mapa geográfico de território e campos

# %%
f, a = plt.subplots()
geo_s.plot(ax=a,edgecolor='k',facecolor='r',alpha=0.4)
geo_cp.plot(ax=a,edgecolor='w',facecolor='g',alpha=1.0);

# %% [markdown]
# - Selecionando poços (onshore ou offshore) que se tornaram públicos em 2022 e em 2023

# %%
# para onshore, 'T' 
p2022_m = p2022_s[p2022_s['TERRA_MAR'] == 'T']
p2022_tcm = p2022_m['CAMPO'].unique()

p2023_m = p2023_s[p2023_s['TERRA_MAR'] == 'T']
p2023_tcm = p2023_m['CAMPO'].unique()

# %% [markdown]
# - Selecionando campos relacionados aos poços

# %%
geo_cp_m_2022 = geo_cp.apply(lambda row: row[geo_cp['NOM_CAMPO'].isin(p2022_tcm)])
geo_cp_m_2023 = geo_cp.apply(lambda row: row[geo_cp['NOM_CAMPO'].isin(p2023_tcm)])

# %% [markdown]
# - Plota campos de interesse

# %%
f, a = plt.subplots()

#geo_s.plot(ax=a,edgecolor='k',facecolor='gray',alpha=.2)
geo_cp_m_2022.plot(ax=a,edgecolor='k',lw=.5,facecolor='lightblue',alpha=.7)
geo_cp_m_2023.plot(ax=a,edgecolor='k',lw=.5,facecolor='darkblue',alpha=.7);

# %% [markdown]
# - Lista de campos participantes da RV

# %%
cp_list_2022 =  geo_cp_m_2022.NOM_CAMPO.tolist()
cp_list_2023 =  geo_cp_m_2023.NOM_CAMPO.tolist()

print('Atividade de divulgação em 2022 nos campos de: ')
print(*[x for x in cp_list_2022], sep=', ', end='.\n\n')

print('Atividade de divulgação em 2023 nos campos de: ')
print(*[x for x in cp_list_2023], sep=', ', end='.\n')
# Out:
# Atividade de divulgação em 2022 nos campos de:
# TIÊ, ARAÇÁS, MATA DE SÃO JOÃO.
#
# Atividade de divulgação em 2023 nos campos de:
# TIÊ.

# %% [markdown]
# ### RV finalística

# %%
f, a = plt.subplots(2,1,figsize=(14,6),sharex=True)

# --- 2022

geo_cp_m_2022.plot(ax=a[0],edgecolor='k',lw=.5,facecolor='lightblue',alpha=.5)
p2022_m_1 = p2022_m[p2022_m['CAMPO'].isin(cp_list_2022)]
p2022_m_1f = sb.scatterplot(data=p2022_m_1,
                              x='LONGITUDE1',
                              y='LATITUDE_1',
                              hue='POCO',
                              marker='o',edgecolor='k',
                              palette='magma',
                              ax=a[0])
p2022_m_1f.legend(bbox_to_anchor=(1.4,1),ncol=2,fontsize=8)

a[0].set_ylabel('Longitude')
a[0].set_title(f'Poços públicos em 2022 - Bacia: {basin}',fontsize=10)

geo_cp_m_2022.apply(lambda x: a[0].annotate(
                            text=f'{x.NOM_CAMPO} ({x.SIG_CAMPO})',
                            xy=np.array(x.geometry.centroid.coords[0]) + np.array([0.15,0]), 
                            ha='left', 
                            va='center',
                            color = "black",
                            fontsize=6, 
                            weight='light'),                            
                            axis=1)


# --- 2023

geo_cp_m_2023.plot(ax=a[1],edgecolor='k',lw=.5,facecolor='darkblue',alpha=.5)
p2023_m_1 = p2023_m[p2023_m['CAMPO'].isin(cp_list_2023)]
p2023_m_1f = sb.scatterplot(data=p2023_m_1,
                             x='LONGITUDE_BASE_DD',
                             y='LATITUDE_BASE_DD',
                             hue='POCO',
                             marker='o',edgecolor='k',
                             palette='cividis',
                             ax=a[1])
p2023_m_1f.legend(bbox_to_anchor=(1.4,1),ncol=2,fontsize=8)

a[1].set_xlabel('Latitude')
a[1].set_ylabel('Longitude')
a[1].set_title(f'Poços públicos em 2023 - Bacia: {basin}',fontsize=10)

geo_cp_m_2023.apply(lambda x: a[1].annotate(
                            text=f'{x.NOM_CAMPO} ({x.SIG_CAMPO})',
                            xy=np.array(x.geometry.centroid.coords[0]) + np.array([0.15,0]), 
                            ha='left', 
                            va='center',
                            color = "black",
                            fontsize=6, 
                            weight='light'),                            
                            axis=1);
